# %% [markdown]
# <figure>
#     <IMG SRC="./pics/Logo.png"  WIDTH=300 ALIGN="right"
# </figure>
#
# ## Investigating sea level scenarios<br>
# ### Scraping NASA
# <b>Prepared by: @@@<br>
# Checked by: @@@ <br>
# Released by: @@@ <br><br>
# Date: 5 April 2022<br>
# Status: Final</b>

# %% [markdown]
# <figure>
#     <IMG SRC="https://www.python.org/static/community_logos/python-powered-w-200x80.png"  WIDTH=150 ALIGN="right">
# </figure>
#
# #### Version history
# - NA

# %% [markdown]
# ### Introduction
# @ Describe what this sheet is about<br>
# @ Describe your working methods, principles and assumptions

# %% [markdown]
# #### Risks and points of attention
# Usually there are a few points you feel are important to communicate. Collect them on the first page of your sheet

# %% [markdown]
# #### References
# Compile your reference list here

# %% [markdown]
# #### Used packages

# %%
# General python packages
import requests
import urllib.request
import time
from bs4 import BeautifulSoup
import os
from io import BytesIO
import pandas as pd

# Company packages

# Project packages

# %% [markdown]
# #### Set URL, connect and get soup

# %%
url = 'https://d3qt3aobtsas2h.cloudfront.net/edge/ws/search/projection?psmsl_id=09&format=csv'
url2 = 'https://d3qt3aobtsas2h.cloudfront.net/edge/ws/search/projection?psmsl_id=?'

# %%
res = requests.get(url)
res
# Out:
# <Response [200]>

# %%
df = pd.read_excel(url, sheet_name = None)

# %%
df['Total']
# Out:
#     psmsl_id process confidence scenario  quantile   2020   2030   2040  \
# 0          9   total     medium   ssp119         5 -0.031 -0.051 -0.036
# 1          9   total     medium   ssp119        17  0.017  0.024  0.051
# 2          9   total     medium   ssp119        50  0.073  0.114  0.154
# 3          9   total     medium   ssp119        83  0.132  0.206  0.265
# 4          9   total     medium   ssp119        95  0.182  0.285  0.360
# 5          9   total     medium   ssp126         5  0.007  0.030  0.055
# 6          9   total     medium   ssp126        17  0.035  0.066  0.101
# 7          9   total     medium   ssp126        50  0.074  0.120  0.171
# 8          9   total     medium   ssp126        83  0.114  0.179  0.249
# 9          9   total     medium   ssp126        95  0.144  0.223  0.308
# 10         9   total     medium   ssp245         5  0.010  0.025  0.062
# 11         9   total     medium   ssp245        17  0.036  0.065  0.108
# 12         9   total     medium   ssp245        50  0.073  0.122  0.176
# 13         9   total     medium   ssp245        83  0.111  0.183  0.251
# 14         9   total     medium   ssp245        95  0.140  0.229  0.310
# 15         9   total     medium   ssp370         5  0.010  0.030  0.060
# 16         9   total     medium   ssp370        17  0.036  0.067  0.107
# 17         9   total     medium   ssp370        50  0.072  0.121  0.177
# 18         9   total     medium   ssp370        83  0.109  0.178  0.255
# 19         9   total     medium   ssp370        95  0.138  0.223  0.315
# 20         9   total     medium   ssp585         5  0.005  0.034  0.076
# 21         9   total     medium   ssp585        17  0.032  0.069  0.120
# 22         9   total     medium   ssp585        50  0.070  0.122  0.187
# 23         9   total     medium   ssp585        83  0.110  0.178  0.263
# 24         9   total     medium   ssp585        95  0.139  0.220  0.322
# 25         9   total        low   ssp126         5  0.007  0.030  0.052
# 26         9   total        low   ssp126        17  0.035  0.066  0.101
# 27         9   total        low   ssp126        50  0.074  0.120  0.172
# 28         9   total        low   ssp126        83  0.114  0.179  0.254
# 29         9   total        low   ssp126        95  0.144  0.223  0.325
# 30         9   total        low   ssp585         5  0.005  0.029  0.062
# 31         9   total        low   ssp585        17  0.031  0.068  0.116
# 32         9   total        low   ssp585        50  0.070  0.120  0.186
# 33         9   total        low   ssp585        83  0.110  0.180  0.277
# 34         9   total        low   ssp585        95  0.139  0.229  0.363
#
#      2050   2060   2070   2080   2090   2100   2110   2120   2130   2140  \
# 0  -0.005  0.019  0.033  0.038  0.074  0.073  0.055  0.057  0.057  0.056
