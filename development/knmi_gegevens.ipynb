# %%
import sys
sys.path.append('s:\\hvec_importers')

# %%
from knmy import knmy
from knmy import parser
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from hvec_importers.knmy import knmy
#       2 from knmy import parser
#
# ModuleNotFoundError: No module named 'hvec_importers.knmy'

# %%
res = knmy.get_knmi_data(
      type = 'daily'
    , stations = [280]
    , start = '20240101'
    , end = '20240331'
    , parse = False
)

# %%
res
# Out:
# '# Opmerking: door stationsverplaatsingen en veranderingen in waarneemmethodieken zijn deze tijdreeksen van uurwaarden mogelijk inhomogeen! Dat betekent dat deze reeks van gemeten waarden niet geschikt is voor trendanalyse. Voor studies naar klimaatverandering verwijzen we naar de gehomogeniseerde dagreeksen <http://www.knmi.nl/nederland-nu/klimatologie/daggegevens> of de Centraal Nederland Temperatuur <http://www.knmi.nl/kennis-en-datacentrum/achtergrond/centraal-nederland-temperatuur-cnt>.\n# \n# SOURCE: ROYAL NETHERLANDS METEOROLOGICAL INSTITUTE (KNMI)\n# Comment: These time series are inhomogeneous because of station relocations and changes in observation techniques. As a result these series are not suitable for trend analysis. For climate change studies we refer to the homogenized series of daily data <http://www.knmi.nl/nederland-nu/klimatologie/daggegevens> or the Central Netherlands Temperature <http://www.knmi.nl/kennis-en-datacentrum/achtergrond/centraal-nederland-temperatu
# ...

# %%
res
# Out:
# '# Opmerking: door stationsverplaatsingen en veranderingen in waarneemmethodieken zijn deze tijdreeksen van uurwaarden mogelijk inhomogeen! Dat betekent dat deze reeks van gemeten waarden niet geschikt is voor trendanalyse. Voor studies naar klimaatverandering verwijzen we naar de gehomogeniseerde dagreeksen <http://www.knmi.nl/nederland-nu/klimatologie/daggegevens> of de Centraal Nederland Temperatuur <http://www.knmi.nl/kennis-en-datacentrum/achtergrond/centraal-nederland-temperatuur-cnt>.\n# \n# SOURCE: ROYAL NETHERLANDS METEOROLOGICAL INSTITUTE (KNMI)\n# Comment: These time series are inhomogeneous because of station relocations and changes in observation techniques. As a result these series are not suitable for trend analysis. For climate change studies we refer to the homogenized series of daily data <http://www.knmi.nl/nederland-nu/klimatologie/daggegevens> or the Central Netherlands Temperature <http://www.knmi.nl/kennis-en-datacentrum/achtergrond/centraal-nederland-temperatu
# ...

# %%
raw_data = knmy.get_hourly_data([209, 257], start=2017010101, end=2017010524)

# %%
raw_data = raw_data.splitlines()

# %%
raw_data[37]
# Out:
# '  209,20170101,    3,  210,  120,  120,  150,     ,     ,     ,     ,     ,     ,     ,     ,     ,     ,     ,     ,    6,     ,     ,     ,     ,     '

# %%
header_raw = 'a,b,b,c'

# %%
header_raw = header_raw.split(',')

# %%
header_raw
# Out:
# ['a', 'b', 'b', 'c']

# %%
header = []

# %%
[header.append(hd) for hd in header_raw]
# Out:
# [None, None, None, None]

# %%
for hd in header_raw:
    print(hd)
    header.append(hd)
# Out:
# a
# b
# b
# c

# %%
header
# Out:
# ['a', 'b', 'b', 'c', 'a', 'b', 'b', 'c']
