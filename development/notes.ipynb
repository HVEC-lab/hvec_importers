# %%
import hvec_importers.ipcc as ipcc
import hvec_importers as importers

# %%
importers.rws?
# Out:
# Object `importers.rws` not found.

# %%
ipcc.data_single_id(24)
# Out:
#     psmsl_id     process confidence scenario  year  median  90%_low  90%_high  \
# 0         24       total     medium   ssp119  2020   0.077   -0.022     0.180
# 1         24       total     medium   ssp126  2020   0.076    0.012     0.144
# 2         24       total     medium   ssp245  2020   0.075    0.015     0.140
# 3         24       total     medium   ssp370  2020   0.074    0.018     0.135
# 4         24       total     medium   ssp585  2020   0.073    0.007     0.142
# ..       ...         ...        ...      ...   ...     ...      ...       ...
# 93        24  totalrates     medium   ssp245  2150   6.900    2.800    14.100
# 94        24  totalrates     medium   ssp370  2150   9.400    4.300    18.200
# 95        24  totalrates     medium   ssp585  2150  10.400    4.400    21.200
# 96        24  totalrates        low   ssp126  2150   5.000   -2.300    16.300
# 97        24  totalrates        low   ssp585  2150  27.300    1.000   119.800
#
#         sigma
# 0    0.062620
# ...
